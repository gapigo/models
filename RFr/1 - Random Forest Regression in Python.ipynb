# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn 
import warnings 

from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Position_Salaries.csv')
print(df)
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
# Assuming df is your DataFrame
X = df.iloc[:, 0:2].values # features
y = df.iloc[:, 2].values    # Target variable

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# Check for and handle categorical variables
label_encoder = LabelEncoder()
x_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
x_numerical = df.select_dtypes(exclude=['object']).values
x = pd.concat([pd.DataFrame(x_numerical), x_categorical], axis=1).values

# Fitting Random Forest Regression to the dataset
regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

# Fit the regressor with x and y data
regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = regressor.predict(x)

# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')

r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.644879832593859
# Mean Squared Error: 2647325000.0
# R-squared: 0.9671801245316117

# %%
x
# Out:
# array([[      1,   45000,       0],
#        [      2,   50000,       4],
#        [      3,   60000,       8],
#        [      4,   80000,       5],
#        [      5,  110000,       3],
#        [      6,  150000,       7],
#        [      7,  200000,       6],
#        [      8,  300000,       9],
#        [      9,  500000,       1],
#        [     10, 1000000,       2]], dtype=int64)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Supondo que X seja bidimensional
X_grid = np.arange(min(X[:, 0]), max(X[:, 0]), 0.01)  # Corrigindo min e max
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color='blue')  # Certifique-se que X e y estão alinhados
plt.plot(X_grid, regressor.predict(X_grid), color='green')  # Regressor deve estar treinado
plt.title("Random Forest Regression Results")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Supondo que X seja bidimensional
# ----> 5 X_grid = np.arange(min(X[:, 0]), max(X[:, 0]), 0.01)  # Corrigindo min e max
#       6 X_grid = X_grid.reshape(len(X_grid), 1)
#       8 plt.scatter(X, y, color='blue')  # Certifique-se que X e y estão alinhados
#
# TypeError: arange() not supported for inputs with DType <class 'numpy.dtypes.StrDType'>.
